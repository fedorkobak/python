# %% [markdown]
# # Creating & loading
#
# Pandas have variety of method to create dataframe or load table as pandas dataframe. This sections consdiers options.
#
# Find out more on the ways to define data frame in the [basics data frame](https://pandas.pydata.org/docs/user_guide/dsintro.html#basics-dataframe) section of the official documentation.

# %%
import pandas as pd

import docker

from sqlalchemy import create_engine
from sqlalchemy.engine import URL 

docker_client = docker.client.from_env()

# %% [markdown]
# ## SQL
#
# One of the most popular options used in production is to load the results of SQL queries as `pandas.DataFrame`. For this purpose, `pandas` has a `read_sql` function that requires a query to be executed and a special object that implements the connection to the database, typically it can be a `sqlalchemy` engine.

# %% [markdown]
# ---
#
# The following cell runs a docker container, so we can try to connect to the database by ourselves.

# %%
container = docker_client.containers.run(
    image="postgres:15.4",
    name="read_postgres_to_pandas",
    detach=True,
    environment={"POSTGRES_USER": "postgres", "POSTGRES_PASSWORD": "password"},
    remove=True,
    ports={"5432/tcp": 5432},
)

# %% [markdown]
# The following cell shows the creation  of the `sqlalchemy` engine and loading some information from it.

# %%
url_object = URL.create(
    "postgresql+psycopg2",
    username="postgres",
    password="password",
    host="localhost",
    port=5432,
    database="postgres",
)
engine = create_engine(url_object)

df = pd.read_sql('SELECT * FROM information_schema.columns', con=engine)
display(df)
# Out:
#      table_catalog        table_schema     table_name  \
# 0         postgres          pg_catalog  pg_init_privs
# 1         postgres          pg_catalog  pg_constraint
# 2         postgres          pg_catalog  pg_constraint
# 3         postgres          pg_catalog  pg_constraint
# 4         postgres          pg_catalog  pg_constraint
# ...            ...                 ...            ...
# 2000      postgres  information_schema       schemata
# 2001      postgres  information_schema       schemata
# 2002      postgres  information_schema       schemata
# 2003      postgres  information_schema       schemata
# 2004      postgres  information_schema      sequences
#
#                         column_name  ordinal_position column_default  \
# 0                          privtype                 4           None
# 1                            conkey                19           None
# 2                           confkey                20           None
# 3                         conpfeqop                21           None
# 4                         conppeqop                22           None
# ...                             ...               ...            ...
# 2000  default_character_set_catalog                 4           None
# 2001   default_character_set_schema                 5           None
# 2002     default_character_set_name                 6           None
# 2003                       sql_path                 7           None
# 2004               sequence_catalog                 1           None
#
#      is_nullable          data_type  character_maximum_length  \
# 0             NO             "char"                       NaN
# 1            YES              ARRAY                       NaN
# 2            YES              ARRAY                       NaN
# 3            YES              ARRAY                       NaN
# 4            YES              ARRAY                       NaN
# ...          ...                ...                       ...
# 2000         YES               name                       NaN
# 2001         YES               name                       NaN
# 2002         YES               name                       NaN
# 2003         YES  character varying                       NaN
# 2004         YES               name                       NaN
#
#       character_octet_length  ...  is_identity  identity_generation  \
# 0                        NaN  ...           NO                 None
# 1                        NaN  ...           NO                 None
# 2                        NaN  ...           NO                 None
# 3                        NaN  ...           NO                 None
# 4                        NaN  ...           NO                 None
# ...                      ...  ...          ...                  ...
# 2000                     NaN  ...           NO                 None
# 2001                     NaN  ...           NO                 None
# 2002                     NaN  ...           NO                 None
# 2003            1.073742e+09  ...           NO                 None
# 2004                     NaN  ...           NO                 None
#
#       identity_start  identity_increment identity_maximum identity_minimum  \
# 0               None                None             None             None
# 1               None                None             None             None
# 2               None                None             None             None
# 3               None                None             None             None
# 4               None                None             None             None
# ...              ...                 ...              ...              ...
# 2000            None                None             None             None
# 2001            None                None             None             None
# 2002            None                None             None             None
# 2003            None                None             None             None
# 2004            None                None             None             None
#
#      identity_cycle is_generated generation_expression is_updatable
# 0                NO        NEVER                  None          YES
# 1                NO        NEVER                  None          YES
# 2                NO        NEVER                  None          YES
# 3                NO        NEVER                  None          YES
# 4                NO        NEVER                  None          YES
# ...             ...          ...                   ...          ...
# 2000             NO        NEVER                  None           NO
# 2001             NO        NEVER                  None           NO
# 2002             NO        NEVER                  None           NO
# 2003             NO        NEVER                  None           NO
# 2004             NO        NEVER                  None           NO
#
# [2005 rows x 44 columns]

# %% [markdown]
# ### Connection url
#
# You can just use the connection url string as the `con` argument of the `read_sql` function. Looks like it still uses `SQLAlchemy` under the hood but it can make things easier.

# %% [markdown]
# ---
#
# The following cell loads `information_schema.columns` as we did before, but uses `con=<connection url>`.

# %%
df = pd.read_sql(
    'SELECT * FROM information_schema.columns',
    con="postgresql+psycopg2://postgres:password@localhost:5432/postgres"
)
display(df)
# Out:
#      table_catalog        table_schema     table_name  \
# 0         postgres          pg_catalog  pg_init_privs
# 1         postgres          pg_catalog  pg_constraint
# 2         postgres          pg_catalog  pg_constraint
# 3         postgres          pg_catalog  pg_constraint
# 4         postgres          pg_catalog  pg_constraint
# ...            ...                 ...            ...
# 2000      postgres  information_schema       schemata
# 2001      postgres  information_schema       schemata
# 2002      postgres  information_schema       schemata
# 2003      postgres  information_schema       schemata
# 2004      postgres  information_schema      sequences
#
#                         column_name  ordinal_position column_default  \
# 0                          privtype                 4           None
# 1                            conkey                19           None
# 2                           confkey                20           None
# 3                         conpfeqop                21           None
# 4                         conppeqop                22           None
# ...                             ...               ...            ...
# 2000  default_character_set_catalog                 4           None
# 2001   default_character_set_schema                 5           None
# 2002     default_character_set_name                 6           None
# 2003                       sql_path                 7           None
# 2004               sequence_catalog                 1           None
#
#      is_nullable          data_type  character_maximum_length  \
# 0             NO             "char"                       NaN
# 1            YES              ARRAY                       NaN
# 2            YES              ARRAY                       NaN
# 3            YES              ARRAY                       NaN
# 4            YES              ARRAY                       NaN
# ...          ...                ...                       ...
# 2000         YES               name                       NaN
# 2001         YES               name                       NaN
# 2002         YES               name                       NaN
# 2003         YES  character varying                       NaN
# 2004         YES               name                       NaN
#
#       character_octet_length  ...  is_identity  identity_generation  \
# 0                        NaN  ...           NO                 None
# 1                        NaN  ...           NO                 None
# 2                        NaN  ...           NO                 None
# 3                        NaN  ...           NO                 None
# 4                        NaN  ...           NO                 None
# ...                      ...  ...          ...                  ...
# 2000                     NaN  ...           NO                 None
# 2001                     NaN  ...           NO                 None
# 2002                     NaN  ...           NO                 None
# 2003            1.073742e+09  ...           NO                 None
# 2004                     NaN  ...           NO                 None
#
#       identity_start  identity_increment identity_maximum identity_minimum  \
# 0               None                None             None             None
# 1               None                None             None             None
# 2               None                None             None             None
# 3               None                None             None             None
# 4               None                None             None             None
# ...              ...                 ...              ...              ...
# 2000            None                None             None             None
# 2001            None                None             None             None
# 2002            None                None             None             None
# 2003            None                None             None             None
# 2004            None                None             None             None
#
#      identity_cycle is_generated generation_expression is_updatable
# 0                NO        NEVER                  None          YES
# 1                NO        NEVER                  None          YES
# 2                NO        NEVER                  None          YES
# 3                NO        NEVER                  None          YES
# 4                NO        NEVER                  None          YES
# ...             ...          ...                   ...          ...
# 2000             NO        NEVER                  None           NO
# 2001             NO        NEVER                  None           NO
# 2002             NO        NEVER                  None           NO
# 2003             NO        NEVER                  None           NO
# 2004             NO        NEVER                  None           NO
#
# [2005 rows x 44 columns]

# %% [markdown]
# Result is the same but much less code.

# %% [markdown]
# ### No SQLAlchemy
#
# It's possible to use the Postgres database without using SQLAlchemy - just pass the `connection object` from `psycopg2` to the `con` parameter of the `read_sql` function.

# %% [markdown]
# ---
#
# The following example shows such a case.

# %%
import psycopg2

conn = psycopg2.connect(
    port="5432",
    dbname="postgres",
    user="postgres",
    password="password",
    host="localhost"
)

df = pd.read_sql('SELECT * FROM information_schema.columns', con=conn)
display(df)
conn.close()
# Out:
# /tmp/ipykernel_81333/3364160090.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM information_schema.columns', con=conn)
#      table_catalog        table_schema     table_name  \
# 0         postgres          pg_catalog  pg_init_privs
# 1         postgres          pg_catalog  pg_constraint
# 2         postgres          pg_catalog  pg_constraint
# 3         postgres          pg_catalog  pg_constraint
# 4         postgres          pg_catalog  pg_constraint
# ...            ...                 ...            ...
# 2000      postgres  information_schema       schemata
# 2001      postgres  information_schema       schemata
# 2002      postgres  information_schema       schemata
# 2003      postgres  information_schema       schemata
# 2004      postgres  information_schema      sequences
#
#                         column_name  ordinal_position column_default  \
# 0                          privtype                 4           None
# 1                            conkey                19           None
# 2                           confkey                20           None
# 3                         conpfeqop                21           None
# 4                         conppeqop                22           None
# ...                             ...               ...            ...
# 2000  default_character_set_catalog                 4           None
# 2001   default_character_set_schema                 5           None
# 2002     default_character_set_name                 6           None
# 2003                       sql_path                 7           None
# 2004               sequence_catalog                 1           None
#
#      is_nullable          data_type  character_maximum_length  \
# 0             NO             "char"                       NaN
# 1            YES              ARRAY                       NaN
# 2            YES              ARRAY                       NaN
# 3            YES              ARRAY                       NaN
# 4            YES              ARRAY                       NaN
# ...          ...                ...                       ...
# 2000         YES               name                       NaN
# 2001         YES               name                       NaN
# 2002         YES               name                       NaN
# 2003         YES  character varying                       NaN
# 2004         YES               name                       NaN
#
#       character_octet_length  ...  is_identity  identity_generation  \
# 0                        NaN  ...           NO                 None
# 1                        NaN  ...           NO                 None
# 2                        NaN  ...           NO                 None
# 3                        NaN  ...           NO                 None
# 4                        NaN  ...           NO                 None
# ...                      ...  ...          ...                  ...
# 2000                     NaN  ...           NO                 None
# 2001                     NaN  ...           NO                 None
# 2002                     NaN  ...           NO                 None
# 2003            1.073742e+09  ...           NO                 None
# 2004                     NaN  ...           NO                 None
#
#       identity_start  identity_increment identity_maximum identity_minimum  \
# 0               None                None             None             None
# 1               None                None             None             None
# 2               None                None             None             None
# 3               None                None             None             None
# 4               None                None             None             None
# ...              ...                 ...              ...              ...
# 2000            None                None             None             None
# 2001            None                None             None             None
# 2002            None                None             None             None
# 2003            None                None             None             None
# 2004            None                None             None             None
#
#      identity_cycle is_generated generation_expression is_updatable
# 0                NO        NEVER                  None          YES
# 1                NO        NEVER                  None          YES
# 2                NO        NEVER                  None          YES
# 3                NO        NEVER                  None          YES
# 4                NO        NEVER                  None          YES
# ...             ...          ...                   ...          ...
# 2000             NO        NEVER                  None           NO
# 2001             NO        NEVER                  None           NO
# 2002             NO        NEVER                  None           NO
# 2003             NO        NEVER                  None           NO
# 2004             NO        NEVER                  None           NO
#
# [2005 rows x 44 columns]

# %% [markdown]
# As a result there is an expected result, but also a warning that advises to use `sqlalchemy`.

# %% [markdown]
# ### List tables
#
# You may face issues with using `\dt` command in postgres to list tables available in the data frame. Use appropritate table -  in postgres case it would be `pg_catalog.pg_tables`.

# %% [markdown]
# ---
#
# The following code tries to run `pd.read_sql` for listing available in the database tables.

# %%
try:
    pd.read_sql("\dt;", con=engine)
except Exception as e:
    print(e)
# Out:
# (psycopg2.errors.SyntaxError) syntax error at or near "\"
# LINE 1: \dt;
#         ^
#
# [SQL: \dt;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_81333/3553204363.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pd.read_sql("\dt;", con=engine)

# %% [markdown]
# The following cell shows you how you're supposed to deal with it.

# %%
pd.read_sql(
    "SELECT * FROM pg_catalog.pg_tables",
    con = engine
)
# Out:
#             schemaname                tablename tableowner tablespace  \
# 0           pg_catalog             pg_statistic   postgres       None
# 1           pg_catalog                  pg_type   postgres       None
# 2           pg_catalog         pg_foreign_table   postgres       None
# 3           pg_catalog                pg_authid   postgres  pg_global
# 4           pg_catalog    pg_statistic_ext_data   postgres       None
# ..                 ...                      ...        ...        ...
# 63          pg_catalog           pg_largeobject   postgres       None
# 64  information_schema             sql_features   postgres       None
# 65  information_schema  sql_implementation_info   postgres       None
# 66  information_schema                sql_parts   postgres       None
# 67  information_schema               sql_sizing   postgres       None
#
#     hasindexes  hasrules  hastriggers  rowsecurity
# 0         True     False        False        False
# 1         True     False        False        False
# 2         True     False        False        False
# 3         True     False        False        False
# 4         True     False        False        False
# ..         ...       ...          ...          ...
# 63        True     False        False        False
# 64       False     False        False        False
# 65       False     False        False        False
# 66       False     False        False        False
# 67       False     False        False        False
#
# [68 rows x 8 columns]
